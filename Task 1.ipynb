# %%
import numpy as np
import illustris_python as il

snapNum = 98
h_Hubble = 0.67
TNG_run = 'TNG50-4'
basePath = './sims.TNG/%s/output/' % TNG_run
gal_fields_to_read = ['SubhaloMass', 'SubhaloMassType', 'SubhaloPos']
Gal_TNG = il.groupcat.loadSubhalos(basePath, snapNum, fields=gal_fields_to_read)

part_num = 4
subhalo_stellar_mass = Gal_TNG['SubhaloMassType'][:, part_num]
subhalo_pos = Gal_TNG['SubhaloPos']

stellar_mass_solar = subhalo_stellar_mass * 1e10 / h_Hubble

dwarfs = stellar_mass_solar < 1e10
dwarf_indices = np.where(dwarfs)[0]

radius_kpc_h = 2000 / h_Hubble

results = []

for dwarf_idx in dwarf_indices:
    dwarf_pos = subhalo_pos[dwarf_idx]

    delta = subhalo_pos - dwarf_pos
    dist = np.linalg.norm(delta, axis=1)  
   
    neighbor_gals = (dist < radius_kpc_h) & (dist > 0) 
    neighbors_indices = np.where(neighbor_gals)[0]
    num_neighbors = len(neighbors_indices)

    
    if num_neighbors > 0:
        
        neighbor_masses = stellar_mass_solar[neighbors_indices]
        max_mass_idx = neighbors_indices[np.argmax(neighbor_masses)]
        max_mass = stellar_mass_solar[max_mass_idx]
    else:
        max_mass_idx = None
        max_mass = None

    results.append({
        'dwarf_index': dwarf_idx,
        'dwarf_stellar_mass': stellar_mass_solar[dwarf_idx],
        'num_neighbors_within_2Mpc': num_neighbors,
        'most_massive_neighbor_index': max_mass_idx,
        'most_massive_neighbor_stellar_mass': max_mass
    })

  
print(f"Total number of dwarf galaxies with M* < 1e10 M_sun: {len(dwarf_indices)}")
    

for r in results:
    print(f"Dwarf galaxy idx {r['dwarf_index']} with stellar mass {r['dwarf_stellar_mass']:.2e} M_sun:")
    print(f"  Number of neighbors within 2 Mpc: {r['num_neighbors_within_2Mpc']}")
    if r['most_massive_neighbor_index'] is not None:
        print(f"  Most massive neighbor idx: {r['most_massive_neighbor_index']} with mass {r['most_massive_neighbor_stellar_mass']:.2e} M_sun")
    else:
        print("  No neighbors within 2 Mpc.")
    print()
# Out:
# Total number of dwarf galaxies with M* < 1e10 M_sun: 22541
# Dwarf galaxy idx 5 with stellar mass 6.94e+09 M_sun:
#   Number of neighbors within 2 Mpc: 554
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 15 with stellar mass 4.67e+09 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 16 with stellar mass 6.42e+09 M_sun:
#   Number of neighbors within 2 Mpc: 550
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 18 with stellar mass 2.68e+09 M_sun:
#   Number of neighbors within 2 Mpc: 536
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 19 with stellar mass 1.99e+08 M_sun:
#   Number of neighbors within 2 Mpc: 541
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 20 with stellar mass 1.94e+08 M_sun:
#   Number of neighbors within 2 Mpc: 538
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 22 with stellar mass 3.77e+08 M_sun:
#   Number of neighbors within 2 Mpc: 532
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 23 with stellar mass 5.98e+09 M_sun:
#   Number of neighbors within 2 Mpc: 548
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 24 with stellar mass 5.00e+09 M_sun:
#   Number of neighbors within 2 Mpc: 550
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 25 with stellar mass 9.54e+09 M_sun:
#   Number of neighbors within 2 Mpc: 554
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 26 with stellar mass 4.09e+09 M_sun:
#   Number of neighbors within 2 Mpc: 556
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 27 with stellar mass 6.60e+08 M_sun:
#   Number of neighbors within 2 Mpc: 553
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 29 with stellar mass 2.40e+08 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 30 with stellar mass 1.48e+09 M_sun:
#   Number of neighbors within 2 Mpc: 558
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx
with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 557
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 246 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 556
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 247 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 539
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 248 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 555
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 249 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 250 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 251 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 546
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 252 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 253 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 541
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 254 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 550
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 255 with stellar mass 2.61e+07 M_sun:
#   Number of neighbors within 2 Mpc: 545
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 256 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 541
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 257 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 545
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 258 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 546
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 259 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 553
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 260 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 261 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 552
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 262 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 558
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 263 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 555
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 264 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 557
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 265 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 540
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 266 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 548
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 267 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 550
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 268 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 554
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 269 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 546
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 270 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 557
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 271 with stellar mass 4.40e+07 M_sun:
#   Number of neighbors within 2 Mpc: 555
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 272 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 558
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 273 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 556
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 274 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 551
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 275 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 540
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 276 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 277 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 552
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 278 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 279 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 280 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 543
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 281 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 547
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 282 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 541
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 283 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 545
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 284 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 545
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 285 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 550
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 286 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 556
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 287 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 288 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 561
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 289 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 541
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 290 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 544
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 291 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 292 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 555
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 293 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 549
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 294 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 552
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 295 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 555
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 296 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 556
#   Most massive neighbor idx: 0 with mass 1.38e+12 M_sun
#
# Dwarf galaxy idx 304 with stellar mass 6.69e+09 M_sun:
#   Number of neighbors within 2 Mpc: 363
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 305 with stellar mass 8.07e+09 M_sun:
#   Number of neighbors within 2 Mpc: 373
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 309 with stellar mass 6.29e+09 M_sun:
#   Number of neighbors within 2 Mpc: 379
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 310 with stellar mass 1.80e+09 M_sun:
#   Number of neighbors within 2 Mpc: 370
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 311 with stellar mass 4.88e+08 M_sun:
#   Number of neighbors within 2 Mpc: 375
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 313 with stellar mass 2.13e+09 M_sun:
#   Number of neighbors within 2 Mpc: 366
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 314 with stellar mass 5.72e+09 M_sun:
#   Number of neighbors within 2 Mpc: 380
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 315 with stellar mass 1.06e+09 M_sun:
#   Number of neighbors within 2 Mpc: 365
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 316 with stellar mass 4.12e+09 M_sun:
#   Number of neighbors within 2 Mpc: 374
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 317 with stellar mass 4.99e+08 M_sun:
#   Number of neighbors within 2 Mpc: 359
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 318 with stellar mass 2.12e+08 M_sun:
#   Number of neighbors within 2 Mpc: 380
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 319 with stellar mass 1.55e+08 M_sun:
#   Number of neighbors within 2 Mpc: 385
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 320 with stellar mass 6.28e+09 M_sun:
#   Number of neighbors within 2 Mpc: 376
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 321 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 389
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 322 with stellar mass 7.16e+08 M_sun:
#   Number of neighbors within 2 Mpc: 381
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 323 with stellar mass 3.30e+09 M_sun:
#   Number of neighbors within 2 Mpc: 381
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 324 with stellar mass 1.18e+08 M_sun:
#   Number of neighbors within 2 Mpc: 362
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 325 with stellar mass 6.55e+08 M_sun:
#   Number of neighbors within 2 Mpc: 380
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 326 with stellar mass 2.77e+08 M_sun:
#   Number of neighbors within 2 Mpc: 378
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 327 with stellar mass 3.71e+08 M_sun:
#   Number of neighbors within 2 Mpc: 379
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 328 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 366
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 329 with stellar mass 2.91e+08 M_sun:
#   Number of neighbors within 2 Mpc: 369
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 330 with stellar mass 1.14e+08 M_sun:
#   Number of neighbors within 2 Mpc: 381
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 331 with stellar mass 3.84e+07 M_sun:
#   Number of neighbors within 2 Mpc: 366
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 332 with stellar mass 1.42e+08 M_sun:
#   Number of neighbors within 2 Mpc: 362
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 333 with stellar mass 3.77e+08 M_sun:
#   Number of neighbors within 2 Mpc: 385
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 334 with stellar mass 1.99e+08 M_sun:
#   Number of neighbors within 2 Mpc: 392
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 335 with stellar mass 1.09e+08 M_sun:
#   Number of neighbors within 2 Mpc: 388
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 336 with stellar mass 1.32e+09 M_sun:
#   Number of neighbors within 2 Mpc: 376
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 337 with stellar mass 5.61e+08 M_sun:
#   Number of neighbors within 2 Mpc: 392
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 338 with stellar mass 3.65e+09 M_sun:
#   Number of neighbors within 2 Mpc: 382
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 339 with stellar mass 6.36e+07 M_sun:
#   Number of neighbors within 2 Mpc: 370
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 340 with stellar mass 4.09e+07 M_sun:
#   Number of neighbors within 2 Mpc: 374
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 341 with stellar mass 1.17e+08 M_sun:
#   Number of neighbors within 2 Mpc: 392
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 342 with stellar mass 2.78e+08 M_sun:
#   Number of neighbors within 2 Mpc: 388
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 343 with stellar mass 4.95e+07 M_sun:
# ...
#   Most massive neighbor idx: 4774 with mass 2.61e+08 M_sun
#
# Dwarf galaxy idx 22782 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 72
#   Most massive neighbor idx: 4012 with mass 8.99e+08 M_sun
#
# Dwarf galaxy idx 22783 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 47
#   Most massive neighbor idx: 2325 with mass 3.55e+10 M_sun
#
# Dwarf galaxy idx 22784 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 27
#   Most massive neighbor idx: 4941 with mass 1.58e+08 M_sun
#
# Dwarf galaxy idx 22785 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 61
#   Most massive neighbor idx: 3588 with mass 8.00e+09 M_sun
#
# Dwarf galaxy idx 22786 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 36
#   Most massive neighbor idx: 2981 with mass 1.68e+10 M_sun
#
# Dwarf galaxy idx 22787 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 44
#   Most massive neighbor idx: 3825 with mass 4.11e+09 M_sun
#
# Dwarf galaxy idx 22788 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 35
#   Most massive neighbor idx: 4072 with mass 5.90e+08 M_sun
#
# Dwarf galaxy idx 22789 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 42
#   Most massive neighbor idx: 3117 with mass 2.09e+10 M_sun
#
# Dwarf galaxy idx 22790 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 33
#   Most massive neighbor idx: 4587 with mass 5.55e+08 M_sun
#
# Dwarf galaxy idx 22791 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 117
#   Most massive neighbor idx: 1863 with mass 4.47e+10 M_sun
#
# Dwarf galaxy idx 22792 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 186
#   Most massive neighbor idx: 793 with mass 8.98e+10 M_sun
#
# Dwarf galaxy idx 22793 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 287
#   Most massive neighbor idx: 793 with mass 8.98e+10 M_sun
#
# Dwarf galaxy idx 22794 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 102
#   Most massive neighbor idx: 3084 with mass 2.25e+10 M_sun
#
# Dwarf galaxy idx 22795 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 66
#   Most massive neighbor idx: 3529 with mass 1.22e+09 M_sun
#
# Dwarf galaxy idx 22796 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 145
#   Most massive neighbor idx: 1742 with mass 1.33e+11 M_sun
#
# Dwarf galaxy idx 22797 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 102
#   Most massive neighbor idx: 3084 with mass 2.25e+10 M_sun
#
# Dwarf galaxy idx 22798 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 69
#   Most massive neighbor idx: 3127 with mass 9.33e+09 M_sun
#
# Dwarf galaxy idx 22799 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 30
#   Most massive neighbor idx: 4573 with mass 7.52e+08 M_sun
#
# Dwarf galaxy idx 22800 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 73
#   Most massive neighbor idx: 4615 with mass 2.57e+08 M_sun
#
# Dwarf galaxy idx 22801 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 122
#   Most massive neighbor idx: 2018 with mass 4.43e+10 M_sun
#
# Dwarf galaxy idx 22802 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 68
#   Most massive neighbor idx: 3078 with mass 1.31e+10 M_sun
#
# Dwarf galaxy idx 22803 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 71
#   Most massive neighbor idx: 3195 with mass 1.05e+10 M_sun
#
# Dwarf galaxy idx 22804 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 55
#   Most massive neighbor idx: 4616 with mass 1.18e+09 M_sun
#
# Dwarf galaxy idx 22805 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 78
#   Most massive neighbor idx: 2460 with mass 4.86e+10 M_sun
#
# Dwarf galaxy idx 22806 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 61
#   Most massive neighbor idx: 3793 with mass 3.42e+09 M_sun
#
# Dwarf galaxy idx 22807 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 121
#   Most massive neighbor idx: 1941 with mass 6.17e+10 M_sun
#
# Dwarf galaxy idx 22808 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 25
#   Most massive neighbor idx: 5599 with mass 6.17e+07 M_sun
#
# Dwarf galaxy idx 22809 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 123
#   Most massive neighbor idx: 1941 with mass 6.17e+10 M_sun
#
# Dwarf galaxy idx 22810 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 61
#   Most massive neighbor idx: 499 with mass 2.82e+09 M_sun
#
# Dwarf galaxy idx 22811 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 63
#   Most massive neighbor idx: 2593 with mass 4.86e+10 M_sun
#
# Dwarf galaxy idx 22812 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 70
#   Most massive neighbor idx: 3477 with mass 4.64e+09 M_sun
#
# Dwarf galaxy idx 22813 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 43
#   Most massive neighbor idx: 4208 with mass 7.74e+08 M_sun
#
# Dwarf galaxy idx 22814 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 77
#   Most massive neighbor idx: 3175 with mass 8.94e+09 M_sun
#
# Dwarf galaxy idx 22815 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 52
#   Most massive neighbor idx: 3825 with mass 4.11e+09 M_sun
#
# Dwarf galaxy idx 22816 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 48
#   Most massive neighbor idx: 3382 with mass 6.73e+09 M_sun
#
# Dwarf galaxy idx 22817 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 267
#   Most massive neighbor idx: 1092 with mass 3.89e+11 M_sun
#
# Dwarf galaxy idx 22818 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 6
#   Most massive neighbor idx: 5735 with mass 4.17e+07 M_sun
#
# Dwarf galaxy idx 22819 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 29
#   Most massive neighbor idx: 3922 with mass 1.34e+09 M_sun
#
# Dwarf galaxy idx 22820 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 88
#   Most massive neighbor idx: 2711 with mass 5.11e+10 M_sun
#
# Dwarf galaxy idx 22821 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 13
#   Most massive neighbor idx: 4212 with mass 2.19e+09 M_sun
#
# Dwarf galaxy idx 22822 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 25
#   Most massive neighbor idx: 4560 with mass 1.19e+08 M_sun
#
# Dwarf galaxy idx 22823 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 59
#   Most massive neighbor idx: 4170 with mass 7.82e+08 M_sun
#
# Dwarf galaxy idx 22824 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 55
#   Most massive neighbor idx: 4475 with mass 4.14e+08 M_sun
#
# Dwarf galaxy idx 22825 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 48
#   Most massive neighbor idx: 4551 with mass 3.13e+08 M_sun
#
# Dwarf galaxy idx 22826 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 32
#   Most massive neighbor idx: 3922 with mass 1.34e+09 M_sun
#
# Dwarf galaxy idx 22827 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 15
#   Most massive neighbor idx: 5154 with mass 2.07e+08 M_sun
#
# Dwarf galaxy idx 22828 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 110
#   Most massive neighbor idx: 2041 with mass 6.59e+10 M_sun
#
# Dwarf galaxy idx 22829 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 38
#   Most massive neighbor idx: 5639 with mass 2.09e+08 M_sun
#
# Dwarf galaxy idx 22830 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 37
#   Most massive neighbor idx: 5639 with mass 2.09e+08 M_sun
#
# Dwarf galaxy idx 22831 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 27
#   Most massive neighbor idx: 4009 with mass 8.70e+08 M_sun
#
# Dwarf galaxy idx 22832 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 242
#   Most massive neighbor idx: 1092 with mass 3.89e+11 M_sun
#
# Dwarf galaxy idx 22833 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 96
#   Most massive neighbor idx: 2711 with mass 5.11e+10 M_sun
#
# Dwarf galaxy idx 22834 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 92
#   Most massive neighbor idx: 3020 with mass 1.39e+10 M_sun
#
# Dwarf galaxy idx 22835 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 122
#   Most massive neighbor idx: 2197 with mass 9.31e+10 M_sun
#
# Dwarf galaxy idx 22836 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 72
#   Most massive neighbor idx: 1941 with mass 6.17e+10 M_sun
#
# Dwarf galaxy idx 22837 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 94
#   Most massive neighbor idx: 3078 with mass 1.31e+10 M_sun
#
# Dwarf galaxy idx 22838 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 124
#   Most massive neighbor idx: 2748 with mass 3.61e+10 M_sun
#
# Dwarf galaxy idx 22839 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 87
#   Most massive neighbor idx: 3604 with mass 5.43e+09 M_sun
#
# Dwarf galaxy idx 22840 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 90
#   Most massive neighbor idx: 3078 with mass 1.31e+10 M_sun
#
# Dwarf galaxy idx 22841 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 102
#   Most massive neighbor idx: 3020 with mass 1.39e+10 M_sun
#
# Dwarf galaxy idx 22842 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 91
#   Most massive neighbor idx: 3020 with mass 1.39e+10 M_sun
#
# Dwarf galaxy idx 22843 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 9
#   Most massive neighbor idx: 7566 with mass 0.00e+00 M_sun
#
# Dwarf galaxy idx 22844 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 87
#   Most massive neighbor idx: 2748 with mass 3.61e+10 M_sun
#
# Dwarf galaxy idx 22845 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 81
#   Most massive neighbor idx: 3084 with mass 2.25e+10 M_sun
#
# Dwarf galaxy idx 22846 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 101
#   Most massive neighbor idx: 2568 with mass 2.51e+10 M_sun
#
# Dwarf galaxy idx 22847 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 83
#   Most massive neighbor idx: 2132 with mass 1.09e+11 M_sun
#
# Dwarf galaxy idx 22848 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 154
#   Most massive neighbor idx: 897 with mass 1.49e+11 M_sun
#
# Dwarf galaxy idx 22849 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 105
#   Most massive neighbor idx: 2568 with mass 2.51e+10 M_sun
#
# Dwarf galaxy idx 22850 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 111
#   Most massive neighbor idx: 2568 with mass 2.51e+10 M_sun
#
# Dwarf galaxy idx 22851 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 31
#   Most massive neighbor idx: 5583 with mass 8.02e+07 M_sun
#
# Dwarf galaxy idx 22852 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 39
#   Most massive neighbor idx: 3837 with mass 5.35e+09 M_sun
#
# Dwarf galaxy idx 22853 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 121
#   Most massive neighbor idx: 2796 with mass 2.82e+10 M_sun
#
# Dwarf galaxy idx 22854 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 26
#   Most massive neighbor idx: 6388 with mass 2.24e+07 M_sun
#
# Dwarf galaxy idx 22855 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 35
#   Most massive neighbor idx: 5065 with mass 7.45e+07 M_sun
#
# Dwarf galaxy idx 22856 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 30
#   Most massive neighbor idx: 4256 with mass 3.36e+08 M_sun
#
# Dwarf galaxy idx 22857 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 29
#   Most massive neighbor idx: 3902 with mass 5.24e+09 M_sun
#
# Dwarf galaxy idx 22858 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 94
#   Most massive neighbor idx: 3084 with mass 2.25e+10 M_sun
#
# Dwarf galaxy idx 22859 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 88
#   Most massive neighbor idx: 3962 with mass 2.59e+09 M_sun
#
# Dwarf galaxy idx 22860 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 204
#   Most massive neighbor idx: 1206 with mass 1.50e+11 M_sun
#
# Dwarf galaxy idx 22861 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 13
#   Most massive neighbor idx: 5045 with mass 1.73e+08 M_sun
#
# Dwarf galaxy idx 22862 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 93
#   Most massive neighbor idx: 627 with mass 5.98e+10 M_sun
#
# Dwarf galaxy idx 22863 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 79
#   Most massive neighbor idx: 3461 with mass 5.65e+09 M_sun
#
# Dwarf galaxy idx 22864 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 67
#   Most massive neighbor idx: 3461 with mass 5.65e+09 M_sun
#
# Dwarf galaxy idx 22865 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 45
#   Most massive neighbor idx: 3326 with mass 2.00e+10 M_sun
#
# Dwarf galaxy idx 22866 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 17
#   Most massive neighbor idx: 7918 with mass 0.00e+00 M_sun
#
# Dwarf galaxy idx 22867 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 95
#   Most massive neighbor idx: 1670 with mass 6.66e+10 M_sun
#
# Dwarf galaxy idx 22868 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 232
#   Most massive neighbor idx: 1206 with mass 1.50e+11 M_sun
#
# Dwarf galaxy idx 22869 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 43
#   Most massive neighbor idx: 3326 with mass 2.00e+10 M_sun
#
# Dwarf galaxy idx 22870 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 51
#   Most massive neighbor idx: 3967 with mass 2.93e+09 M_sun
#
# Dwarf galaxy idx 22871 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 188
#   Most massive neighbor idx: 1424 with mass 1.31e+11 M_sun
#
# Dwarf galaxy idx 22872 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 30
#   Most massive neighbor idx: 3326 with mass 2.00e+10 M_sun
#
# Dwarf galaxy idx 22873 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 82
#   Most massive neighbor idx: 3902 with mass 5.24e+09 M_sun
#
# Dwarf galaxy idx 22874 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 76
#   Most massive neighbor idx: 3902 with mass 5.24e+09 M_sun
#
# Dwarf galaxy idx 22875 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 222
#   Most massive neighbor idx: 998 with mass 2.51e+11 M_sun
#
# Dwarf galaxy idx 22876 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 153
#   Most massive neighbor idx: 1206 with mass 1.50e+11 M_sun
#
# Dwarf galaxy idx 22877 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 157
#   Most massive neighbor idx: 1424 with mass 1.31e+11 M_sun
#
# Dwarf galaxy idx 22878 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 245
#   Most massive neighbor idx: 297 with mass 4.00e+11 M_sun
#
# Dwarf galaxy idx 22879 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 108
#   Most massive neighbor idx: 1206 with mass 1.50e+11 M_sun
#
# Dwarf galaxy idx 22880 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 297
#   Most massive neighbor idx: 998 with mass 2.51e+11 M_sun
#
# Dwarf galaxy idx 22881 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 70
#   Most massive neighbor idx: 2947 with mass 1.59e+10 M_sun
#
# Dwarf galaxy idx 22882 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 117
#   Most massive neighbor idx: 3084 with mass 2.25e+10 M_sun
#
# Dwarf galaxy idx 22883 with stellar mass 0.00e+00 M_sun:
#   Number of neighbors within 2 Mpc: 141
#   Most massive neighbor idx: 2963 with mass 2.78e+10 M_sun
